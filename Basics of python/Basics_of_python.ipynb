# %%
#1.Exercise 1: Prime Numbers
import random
# n is the input number to be check whether it is prime or not
n = 2
# this flag maintains status whether the n is prime or not
primeno_flag = 0

if(n > 1):
    for i in range(2, n):
        if (n % i == 0):
            primeno_flag = 1
            break
    if (primeno_flag == 0):
        print("True")
    else:
        print("False")
else:
    print("False")
#2.Exercise 2: Product of Random Numbers
#generates two random numbers between 1 and 10
r1 =random.randint(1, 10)
print("First random number generated between 0 and 10 is",r1)
r2 =random.randint(1, 10)
print("Second random number generated between 0 and 10 is",r2)
#asks the user to enter the product of these numbers
product=input("Enter the product of above generated 2 random numbers:")
print(product)
output=r1*r2
#program should then check if the user's answer is correct and display an appropriate message.
#input() function returns a string. To compare it with the integer output, we convert output to a string using str(output)
if product == str(output):
 print("User's answer is correct.Actual product and user's answer are %s , %s" % (product, output))
else:
 print("User's answer is not correct.Actual product and user's answer are %s , %s" % (product, output))
#3.Exercise 3: Squares of Even/Odd Numbers
#Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200.
for i in range(100,200):
    if i%2==0:
        print(f'{i} is an even number')
    else:
        print(f'{i} is an odd number')

#4.Exercise 4: Word counter
#write a program to count the number of words in a given text.
original_input_sentence = "This is a sample text. This text will be used to demonstrate the word counter."
input_sentence=original_input_sentence.replace(".","")
input_wordArr = input_sentence.split(" ")

arr_length=len(input_wordArr)
for i in range(0,arr_length):
 counter=0
 word=input_wordArr[i]
 for j in range(0,arr_length):
  if word==input_wordArr[j]:
    counter=counter+1
    
 print(f'The word-{word} occured {counter} time(s) in the sentence- {original_input_sentence}')
#5.Exercise 5: Check for Palindrome
palindrome_input = 'Racecar'
#to filter out all special characters including space and have alphanumeric alone
palindrome_input = ''.join(filter(str.isalnum, palindrome_input))
palindrome_input_arr = list(palindrome_input)
reversed_list=[]

for i in range(len(palindrome_input_arr) - 1, -1, -1):
  reversed_list.extend(str(palindrome_input_arr[i]))
# Convert list of characters to string
reversed_string = ''.join(reversed_list)
#to filter out all special characters including space and have alphanumeric alone
reversed_string = ''.join(filter(str.isalnum, reversed_string))
print(reversed_string)
#compare 2 string ignoring cases
if palindrome_input.casefold()==reversed_string.casefold():
  print('Entered input is palindrome')
else:
  print('Entered input is not a palindrome')
# Out:
# True
# First random number generated between 0 and 10 is 1
# Second random number generated between 0 and 10 is 7
# Enter the product of above generated 2 random numbers: 8
# 8
# User's answer is not correct.Actual product and user's answer are 8 , 7
# 100 is an even number
# 101 is an odd number
# 102 is an even number
# 103 is an odd number
# 104 is an even number
# 105 is an odd number
# 106 is an even number
# 107 is an odd number
# 108 is an even number
# 109 is an odd number
# 110 is an even number
# 111 is an odd number
# 112 is an even number
# 113 is an odd number
# 114 is an even number
# 115 is an odd number
# 116 is an even number
# 117 is an odd number
# 118 is an even number
# 119 is an odd number
# 120 is an even number
# 121 is an odd number
# 122 is an even number
# 123 is an odd number
# 124 is an even number
# 125 is an odd number
# 126 is an even number
# 127 is an odd number
# 128 is an even number
# 129 is an odd number
# 130 is an even number
# ...
